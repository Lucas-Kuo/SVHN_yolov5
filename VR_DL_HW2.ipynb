# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas-Kuo/SVHN_yolov5/blob/master/VR_DL_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mutual usage

# %%
# !git clone https://github.com/Lucas-Kuo/SVHN_yolov5.git
# %cd SVHN_yolov5
# Out:
# Cloning into 'SVHN_yolov5'...
# remote: Enumerating objects: 10036, done.
# remote: Total 10036 (delta 0), reused 0 (delta 0), pack-reused 10036
# Receiving objects: 100% (10036/10036), 10.35 MiB | 20.90 MiB/s, done.
# Resolving deltas: 100% (6953/6953), done.
# /content/SVHN_yolov5

# %%
import gdown
# !pip install PyYAML==6.0
# Out:
# ...
#      |████████████████████████████████| 596 kB 5.2 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
url = "https://drive.google.com/u/0/uc?id=1Fm-avdeNgzhPxhvia0iw9yZzcoOggy7I&export=download"
output = "test.zip"
gdown.download(url, output, quiet=False)

url = "https://drive.google.com/u/0/uc?id=1lrKueI4HrySQDGvpkilQN9BfaMUN7hZi&export=download"
output = "train.zip"
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1Fm-avdeNgzhPxhvia0iw9yZzcoOggy7I&export=download
# To: /content/SVHN_yolov5/test.zip
# 100%|██████████| 273M/273M [00:01<00:00, 199MB/s]
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1lrKueI4HrySQDGvpkilQN9BfaMUN7hZi&export=download
# To: /content/SVHN_yolov5/train.zip
# 100%|██████████| 420M/420M [00:02<00:00, 188MB/s]
# 'train.zip'

# %%
# !mkdir train
# !mkdir test
# !mkdir train/valid
# !unzip train.zip -d train
# !unzip test.zip -d test
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: test/test/72047.png
#   inflating: test/test/124249.png
#   inflating: test/test/249747.png
#   inflating: test/test/231824.png
#   inflating: test/__MACOSX/test/._231824.png
#   inflating: test/test/490269.png
#   inflating: test/test/444986.png
#   inflating: test/test/455653.png
#   inflating: test/test/474845.png
#   inflating: test/test/483573.png
#   inflating: test/test/1698.png
#   inflating: test/__MACOSX/test/._1698.png
#   inflating: test/test/310632.png
#   inflating: test/test/22102.png
#   inflating: test/test/291338.png
#   inflating: test/test/359554.png
#   inflating: test/test/103184.png
#   inflating: test/test/491605.png
#   inflating: test/test/3931.png
#   inflating: test/__MACOSX/test/._3931.png
#   inflating: test/test/295638.png
#   inflating: test/test/245169.png
#   inflating: test/test/417312.png
#   inflating: test/test/12994.png
#   inflating: test/test/470362.png
#   inflating: test/test/261034.png
# ...

# %% [markdown]
# # Training

# %%
# !python mat_to_yolo.py
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# 28403.png
# 28404.png
# 28405.png
# 28406.png
# 28407.png
# 28408.png
# 28409.png
# 28410.png
# 28411.png
# 28412.png
# 28413.png
# 28414.png
# 28415.png
# 28416.png
# 28417.png
# 28418.png
# 28419.png
# 28420.png
# 28421.png
# 28422.png
# 28423.png
# 28424.png
# 28425.png
# 28426.png
# 28427.png
# 28428.png
# 28429.png
# 28430.png
# 28431.png
# 28432.png
# 28433.png
# 28434.png
# 28435.png
# 28436.png
# 28437.png
# 28438.png
# 28439.png
# 28440.png
# 28441.png
# 28442.png
# 28443.png
# 28444.png
# 28445.png
# 28446.png
# 28447.png
# 28448.png
# 28449.png
# 28450.png
# 28451.png
# 28452.png
# 28453.png
# 28454.png
# 28455.png
# 28456.png
# 28457.png
# 28458.png
# 28459.png
# 28460.png
# 28461.png
# 28462.png
# 28463.png
# 28464.png
# 28465.png
# 28466.png
# 28467.png
# 28468.png
# 28469.png
# 28470.png
# 28471.png
# 28472.png
# 28473.png
# 28474.png
# 28475.png
# 28476.png
# 28477.png
# 28478.png
# 28479.png
# 28480.png
# 28481.png
# 28482.png
# 28483.png
# ...

# %%
# !python split.py
# Out:
# Working with 18420
# Working with 3142
# Working with 33181
# Working with 3562
# Working with 1504
# Working with 7256
# Working with 32171
# Working with 6819
# Working with 20767
# Working with 3124
# Working with 32004
# Working with 27673
# Working with 14396
# Working with 31372
# Working with 15635
# Working with 18284
# Working with 32685
# Working with 18477
# Working with 24163
# Working with 32381
# Working with 14185
# Working with 3635
# Working with 12758
# Working with 26829
# Working with 30601
# Working with 24692
# Working with 24910
# Working with 13473
# Working with 770
# Working with 15760
# Working with 20117
# Working with 17610
# Working with 11354
# Working with 10345
# Working with 31256
# Working with 4682
# Working with 21364
# Working with 831
# Working with 635
# Working with 30532
# Working with 16839
# Working with 13181
# Working with 32122
# Working with 2777
# Working with 13105
# Working with 29405
# Working with 17677
# Working with 17110
# ...

# %%
url = 'https://drive.google.com/u/0/uc?id=1dFHvefaSNt-Zc5w_m6Coaz66KJv3730o&export=download'
output = 'best_s32.pt'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1dFHvefaSNt-Zc5w_m6Coaz66KJv3730o&export=download
# To: /content/SVHN_yolov5/best_s32.pt
# 100%|██████████| 14.3M/14.3M [00:00<00:00, 46.0MB/s]
# 'best_s32.pt'

# %%
# !python train.py --data data/svhn.yaml --cfg yolov5l.yaml --batch-size 16 --epochs 5 --img 320
# Out:
# train: weights=yolov5s.pt, cfg=yolov5l.yaml, data=data/svhn.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=5, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/Lucas-Kuo/SVHN_yolov5 ✅
# YOLOv5 🚀 v6.0-110-gc1926e2 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python train.py --data data/svhn.yaml --cfg yolov5s.yaml --batch-size 16 --epochs 10 --weights best_s32.pt --img 320
# Out:
# ...
# train: weights=best_s32.pt, cfg=yolov5s.yaml, data=data/svhn.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=10, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/Lucas-Kuo/SVHN_yolov5 ✅
# YOLOv5 🚀 v6.0-113-gf3eb457 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !zip -r /content/exp_s42.zip runs/train/exp
from google.colab import files
files.download("/content/exp_s42.zip")
# Out:
# updating: runs/train/exp/ (stored 0%)
# updating: runs/train/exp/train_batch2.jpg (deflated 13%)
# updating: runs/train/exp/hyp.yaml (deflated 44%)
# updating: runs/train/exp/val_batch2_labels.jpg (deflated 22%)
# updating: runs/train/exp/opt.yaml (deflated 43%)
# updating: runs/train/exp/labels.jpg (deflated 26%)
# updating: runs/train/exp/val_batch0_pred.jpg (deflated 20%)
# updating: runs/train/exp/events.out.tfevents.1637839177.e7faddbdb240.241.0 (deflated 24%)
# updating: runs/train/exp/weights/ (stored 0%)
# updating: runs/train/exp/weights/last.pt (deflated 8%)
# updating: runs/train/exp/weights/best.pt (deflated 8%)
# updating: runs/train/exp/val_batch2_pred.jpg (deflated 18%)
# updating: runs/train/exp/val_batch1_pred.jpg (deflated 21%)
# updating: runs/train/exp/labels_correlogram.jpg (deflated 15%)
# updating: runs/train/exp/train_batch0.jpg (deflated 15%)
# updating: runs/train/exp/results.png (deflated 7%)
# updating: runs/train/exp/F1_curve.png (deflated 7%)
# ...

# %% [markdown]
# # Evaluation

# %%
import os
import shutil

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9993, done.
# remote: Total 9993 (delta 0), reused 0 (delta 0), pack-reused 9993
# Receiving objects: 100% (9993/9993), 10.32 MiB | 22.21 MiB/s, done.
# Resolving deltas: 100% (6928/6928), done.
# /content/VR_DL_HW2/yolov5

# %%
if os.path.exists("runs/detect"):
  shutil.rmtree("runs/detect")

# %%
# detect.py modification: 
# Line 154: take a way "/gn"
# !python detect.py --weights ../file/content/SVHN-K/runs/train/exp3/weights/best.pt --source ../test/test/ --device 0 --save-txt --save-conf
# Out:
# Traceback (most recent call last):
#   File "detect.py", line 21, in <module>
#     import torch
#   File "/usr/local/lib/python3.7/dist-packages/torch/__init__.py", line 720, in <module>
#     from torch import quantization as quantization
#   File "/usr/local/lib/python3.7/dist-packages/torch/quantization/__init__.py", line 1, in <module>
#     from .quantize import *  # noqa: F403
#   File "/usr/local/lib/python3.7/dist-packages/torch/quantization/quantize.py", line 10, in <module>
#     from torch.ao.quantization.quantize import _convert
#   File "/usr/local/lib/python3.7/dist-packages/torch/ao/quantization/__init__.py", line 4, in <module>
#     from .quantize import *  # noqa: F403
#   File "/usr/local/lib/python3.7/dist-packages/torch/ao/quantization/quantize.py", line 10, in <module>
#     from torch.quantization.quantization_mappings import (
#   File "/usr/local/lib/python3.7/dist-packages/torch/quantization/quantization_mappings.py", line 9, in <module>
# ...

# %%
l = os.listdir("runs/detect/exp/labels")
l[-1]
# Out:
# '400843.txt'

# %%
BASE = "runs/detect/exp2/labels/"
with open(BASE+l[-1], "r") as f:
  lines = f.readlines()
  for line in lines:
    print(line)
# cls x y w h confidence
# 4 127 36 14 32 0.542848

# 6 99 38.5 22 47 0.648589

# 4 76 32.5 24 53 0.761113
# Out:
# 4 127 36 14 32 0.542848
#
# 6 99 38.5 22 47 0.648589
#
# 4 76 32.5 24 53 0.761113

# %%
# %cd ..
# Out:
# /content

# %%
url = "https://drive.google.com/u/4/uc?id=1MB4148TiuoBuxSiUuewmX5Crr0uyTNWa&export=download"
output = "file.zip"
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/u/4/uc?id=1MB4148TiuoBuxSiUuewmX5Crr0uyTNWa&export=download
# To: /content/file.zip
# 100%|██████████| 29.8M/29.8M [00:00<00:00, 76.5MB/s]
# 'file.zip'

# %%
# !mkdir file
# !unzip file.zip -d file
# Out:
# Archive:  file.zip
#    creating: file/content/SVHN-K/runs/train/exp3/
#   inflating: file/content/SVHN-K/runs/train/exp3/opt.yaml
#   inflating: file/content/SVHN-K/runs/train/exp3/train_batch2.jpg
#   inflating: file/content/SVHN-K/runs/train/exp3/R_curve.png
#   inflating: file/content/SVHN-K/runs/train/exp3/F1_curve.png
#   inflating: file/content/SVHN-K/runs/train/exp3/train_batch1.jpg
#   inflating: file/content/SVHN-K/runs/train/exp3/results.png
#   inflating: file/content/SVHN-K/runs/train/exp3/val_batch0_pred.jpg
#   inflating: file/content/SVHN-K/runs/train/exp3/events.out.tfevents.1637026189.e7a2955957c7.385.0
#   inflating: file/content/SVHN-K/runs/train/exp3/labels.jpg
#   inflating: file/content/SVHN-K/runs/train/exp3/P_curve.png
#   inflating: file/content/SVHN-K/runs/train/exp3/val_batch1_labels.jpg
#   inflating: file/content/SVHN-K/runs/train/exp3/labels_correlogram.jpg
#   inflating: file/content/SVHN-K/runs/train/exp3/val_batch0_labels.jpg
# ...

# %%
import torch
import os

# %%
# Model
# model = torch.load('file/content/SVHN-K/runs/train/exp3/weights/best.pt')
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', classes=10)
# model = torch.hub.load('file/content/SVHN-K/runs/train/exp3/weights/best.pt', )\
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# YOLOv5 🚀 2021-11-21 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Overriding model.yaml nc=80 with nc=10
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
# ...

# %%
# model = torch.load('file/content/SVHN-K/runs/train/exp3/weights/best.pt')
# checkpoint_ = torch.load('file/content/SVHN-K/runs/train/exp3/weights/best.pt')['model']
# model.load_state_dict(torch.load('file/content/SVHN-K/runs/train/exp3/weights/best.pt')['model'].state_dict())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-50-c91ff630f4ed> in <module>()
#       1 # model = torch.load('file/content/SVHN-K/runs/train/exp3/weights/best.pt')
#       2 # checkpoint_ = torch.load('file/content/SVHN-K/runs/train/exp3/weights/best.pt')['model']
# ----> 3 model.load_state_dict(torch.load('file/content/SVHN-K/runs/train/exp3/weights/best.pt')['model'].state_dict())
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#    1481         if len(error_msgs) > 0:
#    1482             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# -> 1483                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1484         return _IncompatibleKeys(missing_keys, unexpected_keys)
#    1485
#
# ...

# %%
l = os.listdir("test/test")
BASE_TEST_DIR = "test/test/"

# %%
img = BASE_TEST_DIR + l[0]

# %%
result = model(img)

# %%
result.print()
# Out:
# image 1/1: 52x172 (no detections)
# Speed: 56.9ms pre-process, 195.4ms inference, 61.1ms NMS per image at shape (1, 3, 224, 640)

# %% [markdown]
# # Evaluation2 --> conf=0.001 IOU_thres=0.6

# %%
import os
import shutil
import json

# %%
# url = "https://drive.google.com/u/0/uc?id=1xjZ_8qW6iKv1-evFoPJhlEXX8LxFoYIv&export=download" # s
url = "https://drive.google.com/u/0/uc?id=1J386qflqdWkA_bqJ5dkRardHUpv14APT&export=download" # s_16
# url = "https://drive.google.com/u/0/uc?id=1AT5MY8U8Q9yX2xwz--Y6fH3FpazMmeL3&export=download" # m
# url = "https://drive.google.com/u/0/uc?id=1Tx22Xm4Wa3pN_sM-csjF2yfPfOHnsqib&export=download" # m_9
# url = "https://drive.google.com/u/0/uc?id=1iAVBn4_DI0Nc0CsBdSQ8PGZxywpdYecq&export=download" # m_12
output = "best_s16.pt"
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1J386qflqdWkA_bqJ5dkRardHUpv14APT&export=download
# To: /content/SVHN_yolov5/best_s16.pt
# 100%|██████████| 14.3M/14.3M [00:00<00:00, 173MB/s]
# 'best_s16.pt'

# %% [markdown]
# **Run inference from here everytime!**

# %%
if os.path.exists("runs/detect"):
  shutil.rmtree("runs/detect")

# %%
# Inference
# !python detect.py --weights runs/train/exp/weights/best.pt --source test/test/ --device 0 --save-txt --save-conf --iou-thres 0.6  --conf-thres 0.0001 --nosave --img 320
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=test/test/, imgsz=[320, 320], conf_thres=0.0001, iou_thres=0.6, max_det=1000, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-113-gf3eb457 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7037095 parameters, 0 gradients
# Running inference...
# Inference Speed: 21.2 ms per image
# Results saved to runs/detect/exp
# 13068 labels saved to runs/detect/exp/labels

# %%
# Inference 
# !python detect.py --weights best_s16.pt --source test/test/ --device 0 --save-txt --save-conf --iou-thres 0.6  --conf-thres 0.0001 --nosave
# !python detect.py --weights runs/train/exp2/weights/best.pt --source test/test/ --device 0 --save-txt --save-conf --iou-thres 0.6  --conf-thres 0.001 --nosave
# Out:
# ...
# detect: weights=['best_s16.pt'], source=test/test/, imgsz=[640, 640], conf_thres=0.0001, iou_thres=0.6, max_det=1000, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-110-gc1926e2 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7037095 parameters, 0 gradients
# Running inference...
# Inference Speed: 24.9 ms per image
# Results saved to runs/detect/exp
# 13068 labels saved to runs/detect/exp/labels

# %%
# Inference M
# !python detect.py --weights best.pt --source test/test/ --device 0 --save-txt --save-conf --iou-thres 0.6  --conf-thres 0.0001 --nosave
# Out:
# ...
# detect: weights=['best.pt'], source=test/test/, imgsz=[640, 640], conf_thres=0.0001, iou_thres=0.6, max_det=1000, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-110-gc1926e2 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46156743 parameters, 0 gradients
# Running inference...
# Traceback (most recent call last):
#   File "detect.py", line 246, in <module>
#     main(opt)
#   File "detect.py", line 241, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 28, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 116, in run
#     pred = model(im, augment=augment, visualize=visualize)
# ...

# %%
# Inference L
# !python detect.py --weights runs/train/exp3/weights/best.pt --source test/test/ --device 0 --save-txt --save-conf --iou-thres 0.6  --conf-thres 0.0001 --nosave
# Out:
# detect: weights=['runs/train/exp3/weights/best.pt'], source=test/test/, imgsz=[640, 640], conf_thres=0.0001, iou_thres=0.6, max_det=1000, device=0, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-110-gc1926e2 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46156743 parameters, 0 gradients
# Running inference...
# Inference Speed: 61.3 ms per image
# Results saved to runs/detect/exp
# 13068 labels saved to runs/detect/exp/labels

# %%
answer_dirs = os.listdir("runs/detect/exp/labels")
ANSWER_BASE_DIR = "runs/detect/exp/labels/"
result_to_json = []

answer_dirs.sort(key = lambda x: int(x[:-4]))

for answer_dir in answer_dirs:
  # parse image id from "xxxxx.txt"
  img_id = answer_dir[:-4]
  
  with open(ANSWER_BASE_DIR+answer_dir, "r") as f:
    lines = f.readlines()
    for line in lines:
      det_box_info = {}
      # line contains: {class} {x}{y}{w}{h} {confidence}
      args = line.split()

      det_box_info["image_id"] = int(img_id)
      det_box_info["category_id"] = int(args[0])
      det_box_info["bbox"] = [float(args[1]), float(args[2]), float(args[3]), float(args[4])]
      det_box_info["score"] = float(args[5])

      result_to_json.append(det_box_info)
  
json_object = json.dumps(result_to_json, indent=4)

with open("answer.json", "w") as outfile:
  outfile.write(json_object)
